# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OrdinalEncoder
import matplotlib.pyplot as plt

#df=pd.read_excel('restaurants.xlsx')

# %%
df = pd.read_excel('REST_Analysis_JAPANESE.xlsx')

# %%
df
# Out:
#                                                    name      price  bookmark  \
# 0                                         Yadllie Plate   $101-200     84643
# 1                                            Tearapy 茶聊   $101-200     48235
# 2                                      Outdark (飛達商業中心)   $201-400     45278
# 3                                    Mini Friday (銀城廣場)   $201-400     46949
# 4                                      URBAN Cafe (彌敦道)  Below $50     37840
# ...                                                 ...        ...       ...
# 1395  Saizeriya Italian Restaurant (Panda Place) 薩莉亞...    $51-100      2506
# 1396                                Corner Kitchen 巷仔冰室   $101-200      1485
# 1397  Gyujin Shabu Shabu & Sukiyaki Restaurant (City...   $101-200      1543
# 1398                                                 侍元    $51-100       384
# 1399                                   Genki Sushi 元気寿司   $101-200      1126
#
# ...
