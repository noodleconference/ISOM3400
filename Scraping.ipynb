# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.common.exceptions import NoSuchElementException
import time

import pandas as pd

# %%
driver = webdriver.Chrome('/Users/Jacky/Downloads/chromedriver')
driver.get('https://www.openrice.com/en/hongkong/restaurants/district/causeway-bay?page=1')

# %%
browserbs_sample = BeautifulSoup(driver.page_source, 'lxml')

# %%
#print(browserbs_sample.prettify())
# Out:
# <html class="or-web js flexbox flexboxlegacy canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers no-applicationcache svg inlinesvg smil svgclippaths" lang="en-US">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# website: http://ogp.me/ns/website#">
#   <meta charset="utf-8"/>
#   <title>
#    Hong Kong Restaurant Search : Causeway Bay | OpenRice Hong Kong
#   </title>
#   <meta content="#fff" name="theme-color"/>
#   <meta content="width=1280" name="viewport"/>
#   <link href="//static5.orstatic.com" rel="dns-prefetch"/>
#   <link href="//static6.orstatic.com" rel="dns-prefetch"/>
#   <link href="//static7.orstatic.com" rel="dns-prefetch"/>
#   <link href="//static8.orstatic.com" rel="dns-prefetch"/>
#   <meta content="Hong Kong Restaurant Search : Causeway Bay | OpenRice Hong Kong" property="og:title"/>
#   <meta content="https://www.openrice.com/en/hongkong/restaurants/district/causeway-bay?page=1" property="og:url"/>
#   <meta content="Find Causeway Bay, Food &amp; Dining places in Hong Kong at OpenRice Hong Kong" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="156354557765535" property="fb:app_id"/>
#   <meta content="Find Causeway Bay, Food &amp; Dining places in Hong Kong at OpenRice Hong Kong" name="description"/>
#   <link href="https://www.openrice.com/en/hongkong/restaurants/district/causeway-bay?page=1" rel="canonical"/>
#   <link href="https://www.openrice.com/zh/hongkong/restaurants/district/%E9%8A%85%E9%91%BC%E7%81%A3?page=1" hreflang="zh-HK" rel="alternate"/>
#   <link href="https://www.openrice.com/zh/hongkong/restaurants/district/%E9%8A%85%E9%91%BC%E7%81%A3?page=1" hreflang="zh" rel="alternate"/>
#   <link href="https://www.openrice.com/zh-cn/hongkong/restaurants/district/%E9%93%9C%E9%94%A3%E6%B9%BE?page=1" hreflang="zh-CN" rel="alternate"/>
#   <link href="https://www.openrice.com/en/hongkong/restaurants/district/causeway-bay?page=1" hreflang="en-US" rel="alternate"/>
#   <link href="https://www.openrice.com/en/hongkong/restaurants/district/causeway-bay?page=1" hreflang="en" rel="alternate"/>
#   <link href="https://www.openrice.com/en/hongkong/restaurants/district/causeway-bay?page=1" hreflang="x-default" rel="alternate"/>
#   <link href="/public/manifest.json" rel="manifest"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/OpenRiceSearchProvider" rel="search" title="OpenRice.com" type="application/opensearchdescription+xml"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
#   <style type="text/css">
#    @import url(https://fonts.googleapis.com/earlyaccess/notosanstc.css);
#   </style>
#   <link href="//static5.orstatic.com/bundles/css/v/common.-B4O0fa4ImXWsJtOHCDayMEPm6g2PCgARYK3S-0Vbgw1-v593.css" rel="stylesheet"/>
#   <link href="//static8.orstatic.com/bundles/css/v/or/search.FGKJFoMyp3NPMeAib1igHBpNwozoCJnpn0bKbzsUm0A1-v593.css" rel="stylesheet"/>
#   <link href="//static8.orstatic.com/bundles/css/v/or/booking-picker.I2yx16Rzm8r5rb42kgSHzxO65WTbe-QHG5d74UCCFHM1-v593.css" rel="stylesheet"/>
#   <link href="//static7.orstatic.com/bundles/css/v/or/promotion.hJ-nSxxa_FoczyOoKdLp3F5GH5Akxl07Im2UmRJHMuo1-v593.css" rel="stylesheet"/>
#   <link href="//static5.orstatic.com/bundles/css/v/or/booking.15JInB9sqjWlXH-cf7vHqdatoEzcxw6rlz8AB3XsisE1-v593.css" rel="stylesheet"/>
#   <link href="//static6.orstatic.com/bundles/css/v/or/poi-list.Ss3Cf0HBQopokMBoBm7gVJcmdU5BuKsQ-Vvbdu_rHRs1-v593.css" rel="stylesheet"/>
#   <script async="" src="https://sb.scorecardresearch.com/c2/17405716/cs.js" type="text/javascript">
#   </script>
#   <script id="facebook-jssdk" src="//connect.facebook.net/en_US/sdk.js#xfbml=1&amp;version=v2.8&amp;appId=156354557765535">
#   </script>
#   <script async="" src="https://www.googletagservices.com/tag/js/gpt.js" type="text/javascript">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://stats.g.doubleclick.net/dc.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-K6M5TR">
#   </script>
#   <script async="" src="https://www.googletagservices.com/tag/js/gpt.js" type="text/javascript">
#   </script>
#   <script src="//static8.orstatic.com/bundles/js/v/jquery.adXX0-nm_2oM-hG3-HEc217tE9nteWTgGv0sEo7ak3o1-v593.js">
#   </script>
#   <script data-target='{"language":["en"],"region":["0"],"district":["1019"]}' id="googleTagCustomTargetingScript" type="text/javascript">
#    var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         (function () {
#             var gads = document.createElement("script");
#             gads.async = true;
#             gads.type = "text/javascript";
#             var useSSL = "https:" == document.location.protocol;
#             gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#             var node = document.getElementsByTagName("script")[0];
#             node.parentNode.insertBefore(gads, node);
#         })();
#
#         googletag.cmd.push(function () {
#             googletag.pubads().collapseEmptyDivs();
#             var target = JSON.parse(document.getElementById("googleTagCustomTargetingScript").dataset.target);
#             var sendUserTargeting = localStorage.getItem('user_targeting');
#             if (sendUserTargeting) {
#                 var profile = localStorage.getItem('user_profile');
#                 if (profile) {
#                     target = Object.assign(target, JSON.parse(profile));
#                 }
#             }
#             googletag.pubads().clearTargeting();
#             for (var key in target) {
#                 googletag.pubads().setTargeting(key, target[key]);
#             }
#         });
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?l=dataLayer">
#   </script>
#  </head>
#  <body data-abort-page-reload="false" data-app-author="Asia's Premier Dining Guide" data-app-link="" data-app-name="OpenRice Hong Kong" data-country-code="HK" data-facebook-api-url="//connect.facebook.net/en_US/sdk.js#xfbml=1&amp;version=v2.8&amp;appId=156354557765535" data-facebook-app-id="156354557765535" data-google-api-url="//apis.google.com/js/platform.js" data-google-client-id="681486649361-8c2a5rub1v79k4v1f80h7qfkgskdnfns.apps.googleusercontent.com" data-google-map-key="AIzaSyC2dV18FKK5zBE63OHAPpzaiJE97Few0xg" data-is-mobile-device="0" data-is-phone-signup-only="false" data-logout-return-url="" data-region-cookie-age="" data-region-cookie-name="DefaultRegionIds" data-regionid="0" data-uicity="hongkong" data-uilang="en" ontouchstart="" role="document">
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-K6M5TR" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-K6M5TR');
#   </script>
#   <!-- End Google Tag Manager -->
#   <div id="global-container">
#    <header>
#     <div class="header-warning-block js-header-warning-block hide" id="js-header-warning-block">
#     </div>
#     <div class="hide" data-href="/en/login" data-loginurlbase="/en/login" id="js-login-url">
#     </div>
#     <nav class="header js-feeder js-navigation" data-add-email-frame-url="/en/add-email?frameMode=True" data-city="hongkong" data-controller="Nav" data-country-cookie-age="" data-country-cookie-name="DefaultSite" data-culture-cookie-age="" data-culture-cookie-name="CultureInfo" data-lang="en" data-login-frame-url="/en/login?frameMode=True&amp;regionId=0&amp;countryCode=HK" data-login-write-review-frame-url="/en/login?returnUrl=%2Fen%2Fhongkong%2Freview%2Fwrite&amp;frameMode=True&amp;countryCode=HK" data-region-cookie-age="" data-region-cookie-name="DefaultRegionIds" data-regionid="0" data-signup-frame-url="/en/register?frameMode=True&amp;regionId=0&amp;countryCode=HK" data-unsupport-page="/en/unsupported-browser" data-user-grade-format="Level{0}" id="header" role="navigation">
#      <script src="//static5.orstatic.com/bundles/js/v/unsupported-browser.dREJcSQji6BWkJZr7PiRBbwoQbfOQMr5bNqTNUv8-wk1-v593.js">
#      </script>
#      <div class="header-userbar-container or-font-family" data-ga-source="Header">
#       <div class="header-userbar js-header-userbar" data-controller="CommonPopuplogin">
#        <script id="headerUserbarTemplate" type="text/x-handlebars-template">
#         <a title="F&amp;B Jobs" class="header-userbar-generic-link" data-ga-event="[{&quot;category&quot;:&quot;Job Related&quot;,&quot;action&quot;:&quot;or.job.webGetList&quot;,&quot;label&quot;:&quot;RegionID:0&quot;,&quot;value&quot;:null}]" href="/en/hongkong/jobs/functions">
#         <span class="or-sprite-inline-block nav-ic-job-logged-in"></span>
#     </a>
#
# <a title="Write Review" class="header-userbar-generic-link js-write-review-button" href="/en/hongkong/review/write">
#     <span class="or-sprite-inline-block a_home_header_icon_writereview_desktop"></span>
# </a>
#
# <a title="Bookmark" class="header-userbar-generic-link" href="/en/me/bookmarked-restaurants">
#     <span class="or-sprite-inline-block a_home_header_icon_bookmark_desktop"></span>
# </a>
# <div class="header-user-info-container header-userbar-generic-link">
#     <a title="Me" class="js-user-info user-info">
#         <img class="header-userbar-user-avatar image-circle no-image-rendering" src="{{userPhotoUrl}}" />
#     </a>
#     <div class="header-menu-body-arrow"></div>
#     <div class="header-user-info-container-hover-area"></div>
#     <div class="header-user-info-body-container js-header-user-info-body-container">
#         <a title="Me" class="js-myor-url" href="/en/me">
#             <div class="header-user-info">
#                 <div class="header-user-info-username">{{username}}</div>
#                 <div class="header-user-info-grading">Level{{userGrade}}</div>
#             </div>
#         </a>
#         <div class="header-user-info-body-content">
#             <a href="/en/me/activity-feed">
#                 <div class="header-user-info-body-item">
#                     Activities
#                 </div>
#             </a>
#             <a href="/en/me/bookmarked-restaurants">
#                 <div class="header-user-info-body-item">
#                     Bookmarks
#                 </div>
#             </a>
#                 <a href="/en/me/bookings">
#                     <div class="header-user-info-body-item">
#                         My Booking
#                     </div>
#                 </a>
#
#                 <a href="/en/me/vouchers/available">
#                     <div class="header-user-info-body-item">
#                         My Voucher
#                     </div>
#                 </a>
#
#                 <a href="/en/me/jobs/applied">
#                     <div class="header-user-info-body-item">
#                         My Job Applications
#                     </div>
#                 </a>
#
#                 <a href="https://www.openrice.com/info/newmembertiers/index-en.html?utm_campaign=newmembertiers&amp;utm_medium=web&amp;utm_source=memberlevelswitchedm&amp;utm_content=en&amp;utm_term ">
#                     <div class="header-user-info-body-item">
#                         Membership Levels
#                     </div>
#                 </a>
#
#             <a href="/en/me/reviews">
#                 <div class="header-user-info-body-item">
#                     Reviews
#                 </div>
#             </a>
#             <a href="/en/me/photos">
#                 <div class="header-user-info-body-item">
#                     Photos
#                 </div>
#             </a>
#             <a href="/en/me/dining-points">
#                 <div class="header-user-info-body-item">
#                     My Points
#                 </div>
#             </a>
#             <a href="/en/me/profile">
#                 <div class="header-user-info-body-item">
#                     Settings
#                 </div>
#             </a>
#             <a href="/en/me/personal">
#                 <div class="header-user-info-body-item">
#                     Personal Setting
#                 </div>
#             </a>
#         </div>
#         <a class="js-header-user-info-logout">
#             <div class="header-user-info-logout">
#                 Logout
#             </div>
#         </a>
#     </div>
# </div>
#        </script>
#        <div class="header-userbar-lang-menu">
#         <div class="header-userbar-localmenu-container">
#          <div class="header-userbar-link header-userbar-localmenu" data-current-lang="en">
#           <span class="localmenu-icon or-sprite-inline-block a_home_header_icon_globe_desktop">
#           </span>
#           <span class="localmenu-text">
#            Hong Kong  | ENG
#           </span>
#           <span class="localmenu-icon or-sprite-inline-block a_home_header_arrow_desktop">
#           </span>
#           <div class="header-userbar-localmenu-content js-header-userbar-localmenu-content nav-dropdown">
#            <div class="js-local-menu nav-dropdown-menu-wrapper" data-regionid="0">
#             <div class="js-local-menu nav-dropdown-language-menu" data-regionid="0">
#              <div class="box">
#               <div class="title">
#                Languages
#               </div>
#               <a class="header-userbar-link header-userbar-lang-btn js-header-userbar-lang-btn" data-current-lang="en" data-lang-cookie-name="DefaultSite" data-target-culture="zh-HK" data-target-lang="zh" href="https://www.openrice.com/zh/hongkong/restaurants/district/%E9%8A%85%E9%91%BC%E7%81%A3?page=1">
#                <span class="text">
#                 繁
#                </span>
#               </a>
#               <a class="header-userbar-link header-userbar-lang-btn js-header-userbar-lang-btn" data-current-lang="en" data-lang-cookie-name="DefaultSite" data-target-culture="zh-CN" data-target-lang="zh-cn" href="https://www.openrice.com/zh-cn/hongkong/restaurants/district/%E9%93%9C%E9%94%A3%E6%B9%BE?page=1">
#                <span class="text">
#                 简
#                </span>
#               </a>
#               <a class="header-userbar-link header-userbar-lang-btn js-header-userbar-lang-btn current js-current" data-current-lang="en" data-lang-cookie-name="DefaultSite" data-target-culture="en-US" data-target-lang="en" href="https://www.openrice.com/en/hongkong/restaurants/district/causeway-bay?page=1">
#                <span class="text">
#                 Eng
#                </span>
#               </a>
#              </div>
#             </div>
#             <div class="js-local-menu nav-dropdown-other-country-menu" data-regionid="0">
#              <div class="title">
#               Other Regions
#              </div>
#              <div class="box">
#               <div class="columns">
#                <a class="js-change-country-link js-change-region-link current" data-affinity-country-codes="HK,MO" data-country-code="hk" data-region-id="0" href="https://www.openrice.com/en/hongkong">
#                 <span class="text">
#                  Hong Kong
#                 </span>
#                </a>
#                <a class="js-change-country-link js-change-region-link" data-affinity-country-codes="HK,MO" data-country-code="mo" data-region-id="1" href="https://www.openrice.com/en/macau">
#                 <span class="text">
#                  Macau
#                 </span>
#                </a>
#                <a class="js-change-country-link" data-country-code="tw" href="https://tw.openrice.com/en">
#                 <span class="text">
#                  Taiwan
#                 </span>
#                </a>
#               </div>
#               <div class="columns">
#                <a class="js-change-country-link" data-country-code="jp" href="https://jp.openrice.com/en">
#                 <span class="text">
#                  Japan
#                 </span>
#                </a>
#                <a class="js-change-country-link" data-country-code="th" href="https://th.openrice.com/en">
#                 <span class="text">
#                  Thailand
#                 </span>
#                </a>
#                <a class="js-change-country-link" data-country-code="sg" href="https://sg.openrice.com/en">
#                 <span class="text">
#                  Singapore
#                 </span>
#                </a>
#               </div>
#               <div class="columns">
#                <a class="js-change-country-link" data-country-code="my" href="https://my.openrice.com/en">
#                 <span class="text">
#                  Malaysia
#                 </span>
#                </a>
#                <a class="js-change-country-link" data-country-code="cn" href="https://www.openrice.com.cn/zh">
#                 <span class="text">
#                  China
#                 </span>
#                </a>
#               </div>
#               <div class="clearfix">
#               </div>
#              </div>
#             </div>
#             <div class="checkbox-container">
#              <label class="checkbox js-checkbox">
#               <div class="icon">
#                <div class="or-sprite or-checkbox">
#                </div>
#               </div>
#               <div class="text">
#                Remember my choice
#               </div>
#               <input class="js-nav-remember-local" style="display:none" type="checkbox"/>
#              </label>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="header-userbar-content js-header-userbar-content">
#         <a class="header-userbar-generic-link" data-ga-event='[{"category":"Job Related","action":"or.job.webGetList","label":"RegionID:0","value":null}]' href="/en/hongkong/jobs/functions">
#          F&amp;B Jobs
#         </a>
#         <a class="header-userbar-generic-link" data-href="#loginFormWriteReview">
#          Write Review
#         </a>
#         <a class="header-userbar-generic-link" data-ga-event='[{"category":"User Related","action":"user.login.info","label":"RegionID:0","value":null}]' data-href="#loginForm">
#          Login
#         </a>
#         <a class="header-userbar-generic-link" data-ga-event='[{"category":"User Related","action":"user.signup.info","label":"RegionID:0","value":null}]' data-href="#registration-form">
#          Sign Up
#         </a>
#        </div>
#        <span class="header-userbar-divider">
#        </span>
#        <a class="header-userbar-generic-link" href="/en/hongkong/reports">
#         Update Restaurant Info
#        </a>
#        <a class="header-userbar-generic-link" href="https://biz.openrice.com/hk/en/index" rel="noopener noreferrer" target="_blank">
#         <span class="or-sprite-inline-block a_home_header_icon_hand_desktop">
#         </span>
#         <span class="header-userbar-business-zone-title">
#          Business Zone
#         </span>
#        </a>
#       </div>
#      </div>
#      <div class="header-wrapper">
#       <div class="header-or-logo or-image-2x">
#        <div class="htmlblock htmlblock-debug-container">
#         <a href="/en/hongkong">
#          <img height="40" src="https://www.openrice.com/images/or/a_home_header_logo_or_TC_desktop.png" style="margin-right: 10px" width="144"/>
#         </a>
#        </div>
#       </div>
#       <div class="header-menu-container" data-ga-source="Menu">
#        <div class="header-menu-btn-container">
#         <div class="header-menu-btn-icon or-sprite a_home_header_icon_restaurant_desktop">
#         </div>
#         <div class="header-menu-btn-text or-font-family">
#          Restaurant
#         </div>
#        </div>
#        <div class="header-menu-body-container header-menu-restaurant">
#         <div class="header-menu-body-arrow">
#         </div>
#         <div class="header-menu-body-content">
#          <a data-ga-event='[{"category":"Voucher Related","action":"voucher.list","label":"RegionID:0;PageNo:1","value":null}]' href="/en/hongkong/vouchers">
#           <div class="header-menu-body-item">
#            Vouchers
#           </div>
#          </a>
#          <a data-ga-event='[{"category":"Coupon Related","action":"or.coupon.restaurantOffer","label":"RegionID:0;PageNo:1","value":null}]' href="/en/hongkong/offers">
#           <div class="header-menu-body-item">
#            Coupons
#           </div>
#          </a>
#          <a data-ga-event='[{"category":"Special Listing Related","action":"or.buffet.getlist","label":"RegionID:0","value":null}]' href="/en/hongkong/directory/buffet">
#           <div class="header-menu-body-item">
#            Buffet
#           </div>
#          </a>
#          <a data-ga-event='[{"category":"Special Listing Related","action":"or.hotpot.getlist","label":"RegionID:0","value":null}]' href="/en/hongkong/directory/hotpot">
#           <div class="header-menu-body-item">
#            Hotpot
#           </div>
#          </a>
#          <a data-ga-event='[{"category":"Special Listing Related","action":"or.party.getlist","label":"RegionID:0","value":null}]' href="/en/hongkong/directory/party">
#           <div class="header-menu-body-item">
#            Party
#           </div>
#          </a>
#          <a data-ga-event='[{"category":"Special Listing Related","action":"or.tm.getlist","label":"RegionID:0","value":null}]' href="/en/hongkong/booking-restaurants">
#           <div class="header-menu-body-item">
#            Table Booking
#           </div>
#          </a>
#          <a data-ga-event='[{"category":"Job Related","action":"or.job.function","label":"RegionID:0","value":null}]' href="/en/hongkong/jobs/functions">
#           <div class="header-menu-body-item">
#            F &amp; B Jobs
#           </div>
#          </a>
#          <a data-ga-event='[{"category":"Special Listing Related","action":"or.chart.rating.getlist","label":"RegionID:0","value":null}]' href="/en/hongkong/chart/best-rating">
#           <div class="header-menu-body-item">
#            Restaurant Chart
#           </div>
#          </a>
#          <a data-ga-event='[{"category":"Special Listing Related","action":"or.review.getlist","label":"RegionID:0","value":null}]' href="/en/hongkong/review/index.htm">
#           <div class="header-menu-body-item">
#            Review
#           </div>
#          </a>
#          <a data-ga-event='[{"category":"Special Listing Related","action":"or.newPoi.getlist","label":"RegionID:0","value":null}]' href="/en/hongkong/restaurants?conditionId=2005">
#           <div class="header-menu-body-item">
#            New Restaurant
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="header-menu-container" data-ga-source="Menu">
#        <div class="header-menu-btn-container">
#         <div class="header-menu-btn-icon or-sprite a_home_header_icon_magazine_desktop">
#         </div>
#         <div class="header-menu-btn-text or-font-family">
#          Magazine
#         </div>
#        </div>
#        <div class="header-menu-body-container header-menu-magazine">
#         <div class="header-menu-body-arrow">
#         </div>
#         <div class="header-menu-body-content">
#          <a data-ga-event="" href="/en/hongkong/articles">
#           <div class="header-menu-body-item">
#            Article
#           </div>
#          </a>
#          <a data-ga-event="" href="/en/hongkong/hot-picks">
#           <div class="header-menu-body-item">
#            Hot Picks
#           </div>
#          </a>
#          <a data-ga-event="" href="https://www.openrice.com/info/awards2021/index-en.html">
#           <div class="header-menu-body-item">
#            Restaurant Awards
#           </div>
#          </a>
#          <a data-ga-event="" href="/en/recipe/index.htm">
#           <div class="header-menu-body-item">
#            Recipe
#           </div>
#          </a>
#          <a data-ga-event="" href="https://campaign.openrice.com/video-channel">
#           <div class="header-menu-body-item">
#            Video
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="header-main-group">
#        <div class="header-searchbar-container js-quick-search-container" data-action="/en/hongkong/restaurants" data-gps-lang="Advanced Search" data-landmark-poi-list="/en/hongkong/landmark/restaurants">
#         <div class="header-searchbar-wrapper js-quick-search-wrapper">
#          <div class="header-searchbar-what">
#           <span class="or-sprite-inline-block a_home_header_searchbar_what_desktop">
#           </span>
#           <input autocomplete="off" class="header-searchbar-what-input what js-input-quick-search" data-type="what" name="what" placeholder="Search restaurant name, cuisine, food" type="text"/>
#          </div>
#          <div class="header-searchbar-where">
#           <span class="or-sprite-inline-block a_home_header_searchbar_where_desktop">
#           </span>
#           <input autocomplete="off" class="header-searchbar-where-input where js-input-quick-search" data-type="where" id="header-searchbar-where-input" name="where" placeholder="District, Landmark, Street..." type="text"/>
#          </div>
#          <div class="where quick-search-options js-quick-search-options hidden or-scrollbar" data-type="where">
#           <dl class="category-list">
#            <dt class="category-item">
#            </dt>
#            <dl class="option-list">
#             <dt class="option-item or-section js-option-item" data-param="regionId=0" data-tag="Hong Kong" data-url="">
#              <div class="language-primary">
#               Hong Kong
#              </div>
#             </dt>
#            </dl>
#            <dt class="category-item">
#            </dt>
#            <dl class="option-list">
#             <dt class="option-item or-section js-option-item" data-param="landmarkId=1002" data-tag="Central Station" data-url="">
#              <div class="language-primary">
#               Central Station
#              </div>
#             </dt>
#             <dt class="option-item or-section js-option-item" data-param="landmarkId=1010" data-tag="Tai Koo Station" data-url="">
#              <div class="language-primary">
#               Tai Koo Station
#              </div>
#             </dt>
#             <dt class="option-item or-section js-option-item" data-param="districtId=1019" data-tag="Causeway Bay" data-url="">
#              <div class="language-primary">
#               Causeway Bay
#              </div>
#             </dt>
#            </dl>
#           </dl>
#           <div class="nearby-city">
#            Search in nearby city
#           </div>
#           <div class="nearby-city-container">
#            <a class="nearby-city-item" href="https://www.openrice.com/zh/macau">
#             <div class="nearby-city-item-img" style="background-image:url(/images/or/cityphotos/cityphoto_mac.png?4345)">
#             </div>
#             <div class="nearby-city-item-overlay">
#              澳門
#              <br/>
#              Macau
#             </div>
#            </a>
#            <a class="nearby-city-item" href="https://tw.openrice.com">
#             <div class="nearby-city-item-img" style="background-image:url(/images/or/cityphotos/cityphoto_tw.png?43435)">
#             </div>
#             <div class="nearby-city-item-overlay">
#              台灣
#              <br/>
#              Taiwan
#             </div>
#            </a>
#            <a class="nearby-city-item" href="https://sg.openrice.com">
#             <div class="nearby-city-item-img" style="background-image:url(/images/or/cityphotos/cityphoto_sg.png?43435)">
#             </div>
#             <div class="nearby-city-item-overlay">
#              新加坡
#              <br/>
#              Singapore
#             </div>
#            </a>
#            <a class="nearby-city-item" href="https://th.openrice.com">
#             <div class="nearby-city-item-img" style="background-image:url(/images/or/cityphotos/cityphoto_th.png?43435)">
#             </div>
#             <div class="nearby-city-item-overlay">
#              泰國
#              <br/>
#              Thailand
#             </div>
#            </a>
#           </div>
#          </div>
#          <div class="what quick-search-options js-quick-search-options hidden or-scrollbar" data-type="what">
#           <dl class="category-list">
#            <dt class="category-item">
#            </dt>
#            <dl class="option-list">
#             <dt class="option-item or-section js-option-item" data-param="amenityId=1093" data-tag="Salt &amp; Sugar Reduction Restaurants" data-url="">
#              <div class="language-primary">
#               Salt &amp; Sugar Reduction Restaurants
#              </div>
#             </dt>
#             <dt class="option-item or-section js-option-item" data-param="dishId=1036" data-tag="Dim Sum" data-url="">
#              <div class="language-primary">
#               Dim Sum
#              </div>
#             </dt>
#             <dt class="option-item or-section js-option-item" data-param="promotionId=12" data-tag="Michelin 2021" data-url="">
#              <div class="language-primary">
#               Michelin 2021
#              </div>
#             </dt>
#             <dt class="option-item or-section js-option-item" data-param="amenityId=1008" data-tag="Coffee Shop" data-url="">
#              <div class="language-primary">
#               Coffee Shop
#              </div>
#             </dt>
#             <dt class="option-item or-section js-option-item" data-param="cuisineId=2009" data-tag="Japanese" data-url="">
#              <div class="language-primary">
#               Japanese
#              </div>
#             </dt>
#            </dl>
#           </dl>
#          </div>
#         </div>
#         <button class="btn header-searchbar-search-btn" type="submit">
#          <div class="header-searchbar-search-btn-icon or-sprite a_home_header_searchbar_icon_magnifier_desktop">
#          </div>
#         </button>
#         <div class="header-searchbar-adv-search-btn or-font-family js-btn-advance-search-open" data-href="#search">
#          Advanced
#         </div>
#         <div class="header-searchbar-mapview-btn js-map-search-button" data-mapsearch-url="/en/hongkong/restaurants-map">
#          <span class="or-sprite-inline-block common_btn_map_desktop">
#          </span>
#         </div>
#         <script id="quickSearchOptionTemplate" type="text/x-handlebars-template">
#          <dl class="category-list">
#
#     {{#each data}}
#     {{#if tips}}
#     <dt class="category-item">
#         {{#if nameUI}}
#         <div class="category-title">{{nameUI}}</div>
#         {{/if}}
#
#         <dl class="option-list">
#             {{#each tips}}
#             {{#if name}}
#             <dt class="option-item or-section js-option-item" data-param="{{searchKey}}" data-tag="{{name}}" data-url="{{urlUI}}">
#                 <div class="language-primary">
#                     {{name}}{{#if location}} ({{location}}){{/if}}
#                     {{#if withOffer}}
#                     <span class="or-sprite-inline-block common_icon_offer_desktop has-offer-icon"></span>
#                     {{/if}}
#                 </div>
#                 {{#if desc}}
#                 <div class="language-secondary">{{desc}}</div>
#                 {{/if}}
#             </dt>
#             {{/if}}
#             {{/each}}
#
#             {{#if poiListUrl}}
#             <dt class="option-item or-section js-option-item js-not-highlight-item" data-url="{{poiListUrl}}">
#                 <div class="option-more-results">
#                     <div>View all restaurants</div>
#                     <div class="or-sprite-inline-block common_filter_ar_right_gr_desktop arrow"></div>
#                 </div>
#             </dt>
#             {{/if}}
#         </dl>
#     </dt>
#     {{/if}}
#     {{/each}}
# </dl>
#         </script>
#        </div>
#       </div>
#      </div>
#     </nav>
#     <script id="quicksearch-footer-template" type="text/html">
#      <div class="nearby-city">Search in nearby city</div>
#         <div class="nearby-city-container">
#                     <a class="nearby-city-item" href="https://www.openrice.com/zh/macau">
#                         <div class="nearby-city-item-img" style="background-image:url(/images/or/cityphotos/cityphoto_mac.png?4345)"></div>
#                         <div class="nearby-city-item-overlay">澳門<br/>Macau</div>
#                     </a>
#                     <a class="nearby-city-item" href="https://tw.openrice.com">
#                         <div class="nearby-city-item-img" style="background-image:url(/images/or/cityphotos/cityphoto_tw.png?43435)"></div>
#                         <div class="nearby-city-item-overlay">台灣<br/>Taiwan</div>
#                     </a>
#                     <a class="nearby-city-item" href="https://sg.openrice.com">
#                         <div class="nearby-city-item-img" style="background-image:url(/images/or/cityphotos/cityphoto_sg.png?43435)"></div>
#                         <div class="nearby-city-item-overlay">新加坡<br/>Singapore</div>
#                     </a>
#                     <a class="nearby-city-item" href="https://th.openrice.com">
#                         <div class="nearby-city-item-img" style="background-image:url(/images/or/cityphotos/cityphoto_th.png?43435)"></div>
#                         <div class="nearby-city-item-overlay">泰國<br/>Thailand</div>
#                     </a>
#
#         </div>
#     </script>
#    </header>
#    <main role="main">
#     <!--import below used to check for empty model-->
#     <div class="promotion-background-container rms-background-container js-rms-background-container">
#     </div>
#     <!-- Start Content -->
#     <section class="pois-listing-header">
#      <div class="js-rms-search-header">
#      </div>
#      <div class="js-search-header">
#       <div class="pois-list-header-title-only js-list-base">
#        <div class="content-container">
#         <div class="pois-list-bread-crumb-header-title-wrapper">
#          <h1 class="pois-list-bread-crumb-header-title or-font-family">
#           Restaurant in Causeway Bay
#          </h1>
#          <div class="pois-list-bread-crumb-header-page-navigation">
#           <ul class="breadcrumb">
#            <li class="breadcrumb-item" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#             <a href="/en/hongkong" itemprop="url">
#              <span itemprop="title">
#               Home
#              </span>
#             </a>
#            </li>
#            <li class="breadcrumb-item" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#             <a href="/en/hongkong/restaurants" itemprop="url">
#              <span itemprop="title">
#               Restaurant
#              </span>
#             </a>
#            </li>
#            <li class="breadcrumb-item" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#             <a href="/en/hongkong" itemprop="url">
#              <span itemprop="title">
#               Hong Kong
#              </span>
#             </a>
#            </li>
#            <li class="breadcrumb-item" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#             <span class="active" itemprop="title">
#              Causeway Bay
#             </span>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="pois-list-bread-crumb-header-view-toggle">
#          <div class="view-toggle view-toggle-listview">
#           <div class="view-toogle-text">
#            List View
#           </div>
#          </div>
#          <div class="view-toggle view-toggle-mapview">
#           <div class="view-toogle-text">
#            <a href="/en/hongkong/restaurants-map/district/causeway-bay?page=1&amp;mapType=1">
#             Map View
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="pois-listing-ads-container">
#      <section class="pois-left-skyscraper-ad">
#       <div class="htmlblock htmlblock-debug-container">
#        <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#        </script>
#        <script>
#         window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/1012872/orhk_web_SR1_skyscraper_left', [[130, 800], [125, 840], [120, 600], [160, 600]], 'div-gpt-ad-1575627436640-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
#        </script>
#        <!-- /1012872/orhk_web_SR1_skyscraper_left -->
#        <div id="div-gpt-ad-1575627436640-0">
#         <script>
#          googletag.cmd.push(function() { googletag.display('div-gpt-ad-1575627436640-0'); });
#         </script>
#        </div>
#       </div>
#      </section>
#      <section class="pois-right-skyscraper-ad">
#       <div class="htmlblock htmlblock-debug-container">
#        <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#        </script>
#        <script>
#         var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#        </script>
#        <script>
#         googletag.cmd.push(function() {
#     googletag.defineSlot('/1012872/orhk_web_SR1_skyscraper_right', [[160, 600], [120, 600], [125, 841], [130, 801]], 'div-gpt-ad-1559116989386-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
#        </script>
#        <!-- /1012872/orhk_web_SR1_skyscraper_right -->
#        <div id="div-gpt-ad-1559116989386-0">
#         <script>
#          googletag.cmd.push(function() { googletag.display('div-gpt-ad-1559116989386-0'); });
#         </script>
#        </div>
#       </div>
#      </section>
#      <section class="pois-top-ad wide">
#       <div class="htmlblock htmlblock-debug-container">
#        <center>
#         <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#         </script>
#         <script>
#          window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/1012872/orhk_web_SR1_pushdown(wide)', [[1180, 220], [1180, 200], [970, 250], [1180, 1], [970, 90], [728, 90]], 'div-gpt-ad-1603506628024-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
#         </script>
#         <!-- /1012872/orhk_web_SR1_pushdown(wide) -->
#         <div id="div-gpt-ad-1603506628024-0">
#          <script>
#           googletag.cmd.push(function() { googletag.display('div-gpt-ad-1603506628024-0'); });
#          </script>
#         </div>
#        </center>
#       </div>
#      </section>
#      <section class="pois-top-ad narrow">
#       <div class="htmlblock htmlblock-debug-container">
#        <center>
#         <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#         </script>
#         <script>
#          window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/1012872/orhk_web_SR1_pushdown(narrow)', [[980, 200], [728, 90], [980, 1], [970, 250], [970, 90], [980, 220]], 'div-gpt-ad-1603506256627-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
#         </script>
#         <!-- /1012872/orhk_web_SR1_pushdown(narrow) -->
#         <div id="div-gpt-ad-1603506256627-0">
#          <script>
#           googletag.cmd.push(function() { googletag.display('div-gpt-ad-1603506256627-0'); });
#          </script>
#         </div>
#        </center>
#       </div>
#      </section>
#     </section>
#     <section class="sr1-center-content-wrapper js-sr1-center-content-wrapper" data-api-entry-point="" data-default-ga-action-prefix="or.search" data-delivery-code="" data-dine-in="" data-filter-by-delivery-code="" data-ga-action-prefix="or.search" data-is-organic-layout="false" data-merchant-offer="" data-my-queue="" data-primary-hash="" data-primary-param="districtId=1019" data-primary-param-type="" data-takeaway="" data-takeaway-new-activation="">
#      <section class="pois-left-panel js-pois-left-panel" data-controller="PoiListFilters">
#       <section class="sr1-filter sr1-left-filter pois-filter js-pois-filter">
#        <div class="or-section-container sr1-filter-tag">
#         <div class="sr1-filter-tag-container js-sr1-filter-tag-container js-filter-tag-container" id="sr1-filters-filter-tag-container">
#          <ul class="filter-tag-list js-filter-tag-list">
#           <h4 class="header">
#            Current Tag
#           </h4>
#           <li class="filter-tag-item js-filter-tag-item" data-filter="district" data-param="districtId=1019" data-tag="Causeway Bay">
#            <span>
#             Causeway Bay
#            </span>
#            <div class="filter-tag-item-remove-button js-filter-tag-item-remove-button">
#             <div class="or-sprite common_filter_tag_close_desktop">
#             </div>
#            </div>
#           </li>
#           <li class="filter-tag-item filter-tag-clear-button js-filter-tag-clear-button">
#            clear all
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="or-section-container autocomplete-section js-collapsable-section">
#         <h4 class="header">
#          Location
#         </h4>
#         <div class="or-search-section or-section or-section-fixed-height js-collapsable-search-section" data-target="#locationFilter" data-toggle="collapse">
#          <input placeholder="Type to filter"/>
#          <div class="nav-arrow">
#           <div class="or-sprite common_filter_ar_down_desktop">
#           </div>
#          </div>
#         </div>
#         <div class="dropdown-section-content-container collapse in" data-filter="station district hotel mall" id="locationFilter">
#          <div class="js-locationFilter">
#           <ul class="dropdown-section-content-container-options js-dropdown-section-content-container-options">
#            <li class="dropdown-section-content-container-options-item js-dropdown-section-content-container-options-item js-filter-tag-item" data-count="1195" data-filter="district" data-param="districtId=1019" data-selected="True" data-synonyms="銅鑼灣||Causeway Bay||铜锣湾" data-tag="Causeway Bay" data-toggle="select">
#             <a class="js-filter-tag-item-remove-button" title="Causeway Bay">
#              <span class="name">
#               Causeway Bay
#              </span>
#              <span class="count">
#               (1195)
#              </span>
#             </a>
#            </li>
#            <li class="dropdown-section-content-container-options-item js-dropdown-section-content-container-options-item js-filter-tag-item" data-count="1195" data-filter="district" data-param="districtId=1999" data-selected="False" data-synonyms="香港島||Hong Kong Island||香港岛" data-tag="Hong Kong Island" data-toggle="select">
#             <a class="js-filter-tag-item-remove-button" title="Hong Kong Island">
#              <span class="name">
#               Hong Kong Island
#              </span>
#              <span class="count">
#               (1195)
#              </span>
#             </a>
#            </li>
#            <li class="dropdown-section-content-container-options-item js-dropdown-section-content-container-options-item js-filter-tag-item" data-count="922" data-filter="station" data-param="landmarkId=1005" data-selected="False" data-synonyms="銅鑼灣站||Causeway Bay Station||铜锣湾站" data-tag="Causeway Bay Station" data-toggle="select">
#             <a class="js-filter-tag-item-remove-button" title="Causeway Bay Station">
#              <span class="name">
#               Causeway Bay Station
#              </span>
#              <span class="count">
#               (922)
#              </span>
#             </a>
#            </li>
#            <li class="dropdown-section-content-container-options-item js-dropdown-section-content-container-options-item js-filter-tag-item" data-count="55" data-filter="mall" data-param="landmarkId=7" data-selected="False" data-synonyms="時代廣場||Times Square||时代广场" data-tag="Times Square" data-toggle="select">
#             <a class="js-filter-tag-item-remove-button" title="Times Square">
#              <span class="name">
#               Times Square
#              </span>
#              <span class="count">
#               (55)
#              </span>
#             </a>
#            </li>
#            <li class="dropdown-section-content-container-options-item js-dropdown-section-content-container-options-item js-filter-tag-item" data-count="46" data-filter="mall" data-param="landmarkId=6" data-selected="False" data-synonyms="銅鑼灣崇光百貨||Sogo (Causeway Bay)||崇光百货" data-tag="Sogo (Causeway Bay)" data-toggle="select">
#             <a class="js-filter-tag-item-remove-button" title="Sogo (Causeway Bay)">
#              <span class="name">
#               Sogo (Causeway Bay)
#              </span>
#              <span class="count">
#               (46)
#              </span>
#             </a>
#            </li>
#            <li class="dropdown-section-content-container-options-item js-dropdown-section-content-container-options-item js-filter-tag-item" data-count="43" data-filter="mall" data-param="landmarkId=9314" data-selected="False" data-synonyms="希慎廣場||Hysan Place||希慎广场" data-tag="Hysan Place" data-toggle="select">
#             <a class="js-filter-tag-item-remove-button" title="Hysan Place">
#              <span class="name">
#               Hysan Place
#              </span>
#              <span class="count">
#               (43)
#              </span>
#             </a>
#            </li>
#            <li class="dropdown-section-content-container-options-item js-dropdown-section-content-container-options-item js-filter-tag-item" data-count="41" data-filter="mall" data-param="landmarkId=90" data-selected="False" data-synonyms="利園||Lee Gardens||利园" data-tag="Lee Gardens" data-toggle="select">
#             <a class="js-filter-tag-item-remove-button" title="Lee Gardens">
#              <span class="name">
#               Lee Gardens
#              </span>
#              <span class="count">
#               (41)
#              </span>
#             </a>
#            </li>
#            <li class="dropdown-section-content-container-options-item js-dropdown-section-content-container-options-item js-filter-tag-item" data-count="27" data-filter="mall" data-param="landmarkId=9313" data-selected="False" data-synonyms="Fashion Walk" data-tag="Fashion Walk" data-toggle="select">
#             <a class="js-filter-tag-item-remove-button" title="Fashion Walk">
#              <span class="name">
#               Fashion Walk
#              </span>
#              <span class="count">
#               (27)
#              </span>
#             </a>
#            </li>
#            <li class="dropdown-section-content-container-options-item js-dropdown-section-content-container-options-item js-filter-tag-item" data-count="24" data-filter="mall" data-param="landmarkId=76" data-selected="False" data-synonyms="皇室堡||Windsor House" data-tag="Windsor House" data-toggle="select">
#             <a class="js-filter-tag-item-remove-button" title="Windsor House">
#              <span class="name">
#               Windsor House
#              </span>
#              <span class="count">
#               (24)
#              </span>
#             </a>
#            </li>
#            <li class="dropdown-section-content-container-options-item js-dropdown-section-content-container-options-item js-filter-tag-item" data-count="23" data-filter="mall" data-param="landmarkId=9316" data-selected="False" data-synonyms="永光中心||Circle Tower" data-tag="Circle Tower" data-toggle="select">
#             <a class="js-filter-tag-item-remove-button" title="Circle Tower">
#              <span class="name">
#               Circle Tower
#              </span>
#              <span class="count">
#               (23)
#              </span>
#             </a>
#            </li>
#            <li class="dropdown-section-content-container-options-item js-dropdown-section-content-container-options-item js-filter-tag-item" data-count="22" data-filter="mall" data-param="landmarkId=74" data-selected="False" data-synonyms="利舞臺廣場||Lee Theatre Plaza||利舞台广场" data-tag="Lee Theatre Plaza" data-toggle="select">
# ...
#            <li>
#             <a href="/en/hongkong/restaurants?conditionId=2005" target="_blank">
#              New Restaurant
#             </a>
#            </li>
#            <li>
#             <a href="/en/hongkong/restaurant/advancesearch.htm" target="_blank">
#              Restaurant Search
#             </a>
#            </li>
#            <li>
#             <a href="/en/hongkong/vouchers" target="_blank">
#              Vouchers
#             </a>
#            </li>
#            <li>
#             <a href="/en/hongkong/offers" target="_blank">
#              Coupon
#             </a>
#            </li>
#            <li>
#             <a href="/en/recipe/index.htm" target="_blank">
#              Recipe
#             </a>
#            </li>
#            <li>
#             <a href="http://campaign.openrice.com/activities-en/" target="_blank">
#              Activity
#             </a>
#            </li>
#            <li>
#             <a href="/en/hongkong/restaurant/report_step1.htm" target="_blank">
#              Submit Restaurant Info
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="footer-sitemap-grid">
#           <div class="footer-title">
#            Awards
#           </div>
#           <ul>
#            <li>
#             <a href="https://www.openrice.com/info/awards2021/index-en.html?utm_campaign=awards2021&amp;utm_medium=banner&amp;utm_source=or&amp;utm_content=footer&amp;utm_term=en
# " target="_blank">
#              OpenRice Best Restaurant
#              <br/>
#              Awards 2021
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="footer-sitemap-grid">
#           <div class="footer-title">
#            Review
#           </div>
#           <ul>
#            <li>
#             <a href="/en/hongkong/review/write" target="_blank">
#              Submit Review
#             </a>
#            </li>
#            <li>
#             <a href="/en/hongkong/restaurant/review/search.htm" target="_blank">
#              Latest Review
#             </a>
#            </li>
#           </ul>
#           <div class="footer-title">
#            Gourmet
#           </div>
#           <ul>
#            <li>
#             <a href="/en/hongkong/myopenrice/index.htm " target="_blank">
#              My OpenRice
#             </a>
#            </li>
#            <li>
#             <a href="https://www.openrice.com/info/newmembertiers/index-en.html?utm_campaign=newmembertiers&amp;utm_medium=web&amp;utm_source=footer&amp;utm_content=en&amp;utm_term=" target="_blank">
#              Membership Levels
#             </a>
#            </li>
#            <li>
#             <a href="/en/registration/register.htm?src=orweb&amp;loginurl=http%3A%2F%2Fwww.openrice.com%2Fmyopenrice%2Findex.htm&amp;city=hongkong" target="_blank">
#              Member Registration
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="footer-sitemap-grid">
#           <div class="footer-title">
#            Overseas
#           </div>
#           <ul>
#            <li>
#             <a href="http://www.openrice.com.cn/" target="_blank">
#              开饭喇 中国
#             </a>
#            </li>
#            <li>
#             <a href="http://tw.openrice.com/en" target="_blank">
#              開飯喇 台灣
#             </a>
#            </li>
#            <li>
#             <a href="/zh/macau" target="_blank">
#              開飯喇 澳門
#             </a>
#            </li>
#            <li>
#             <a href="http://jp.openrice.com/zh/tokyo" target="_blank">
#              開飯喇 日本
#             </a>
#            </li>
#            <li>
#             <a href="http://my.openrice.com/info/landing/index.html" target="_blank">
#              OpenRice Malaysia
#             </a>
#            </li>
#            <li>
#             <a href="http://sg.openrice.com/singapore/restaurant/index.htm" target="_blank">
#              OpenRice Singapore
#             </a>
#            </li>
#            <li>
#             <a href="http://th.openrice.com/info/landing-page/index.html" target="_blank">
#              OpenRice Thailand
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="footer-sitemap-grid">
#           <div class="footer-title">
#            Others
#           </div>
#           <ul>
#            <li>
#             <a href="/zh/hongkong/restaurant/index.htm" target="_blank">
#              OpenRice in Chinese
#             </a>
#            </li>
#            <li>
#             <a href="http://travel.openrice.com/home/index.htm" target="_blank">
#              OpenRice Travel
#             </a>
#            </li>
#            <!-- <li><a href="http://www.opensnap.com/" target="_blank">OpenSnap</a></li> -->
#            <li>
#             <a href="/Love" target="_blank">
#              OpenRice Love
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="footer-sitemap-grid">
#           <div class="footer-title">
#            More
#           </div>
#           <ul>
#            <li>
#             <a href="https://blog.openrice.com/" target="_blank">
#              Editor's Blog
#             </a>
#            </li>
#            <li>
#             <a href="https://www.openrice.com/info/aboutus/index-en.html" target="_blank">
#              About Us
#             </a>
#            </li>
#            <li>
#             <a href="/en/hongkong/restaurant/opinion.htm" target="_blank">
#              Contact Us
#             </a>
#            </li>
#            <li>
#             <a href="http://campaign.openrice.com/faq-en/" target="_blank">
#              FAQ
#             </a>
#            </li>
#            <li>
#             <a href="/info/tnc/or-pp-en.html" target="_blank">
#              Privacy Policy
#             </a>
#            </li>
#            <li>
#             <a href="/info/tnc/or-terms-en.html" target="_blank">
#              Terms &amp; Conditions
#             </a>
#            </li>
#            <li>
#             <a href="https://www.openrice.com/info/tnc/terms-of-merchant-services-en.html" target="_blank">
#              Terms of Merchant Services
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="footer-footnote clearfix">
#          <div class="footer-footnote-copyright pull-left">
#           OpenRice, the most popular dining guide in Hong Kong which has expanded to various Asian regions, provides you with comprehensive dining information, restaurant reviews and ratings. You can easily search and enjoy the best restaurants and local cuisines by using our services of online table booking, vouchers, remote queuing, take away and food delivery with just a few clicks!　© 2021 Openrice Group Inc. All Rights Reserved.
#          </div>
#          <div class="footer-footnote-logo or-sprite caring-company-logo">
#          </div>
#          <a class="winning-block" href="https://www.openrice.com/info/nielsen-2017/index-en.html?utm_campaign=OR_Nielsen17&amp;utm_medium=Banner&amp;utm_source=OR&amp;utm_content=Footer&amp;utm_term=en" target="_new">
#           <div class="pull-left or-sprite a_home_sitemap_icon_winning_desktop">
#           </div>
#           <span class="winning-text">
#            Hong Kong's Most Popular
#            <br/>
#            Dining Guide
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="js-not-support-browser-message hidden" hidden="" id="js-not-support-browser-message">
#      <div class="header-warning js-header-warning">
#       <div class="or-sprite n_misc_icon_alert_desktop">
#       </div>
#       <div class="header-warning-message">
#        We don't support Internet Explorer 10 or lower version, please upgrade or switch to other browser:
#        <span class="warning-message-high-light">
#         FireFox 45.0
#        </span>
#        or
#        <span class="warning-message-high-light">
#         Chrome 48.0
#        </span>
#        or above.
#       </div>
#       <div class="or-sprite n_misc_btn_close_desktop header-warning-close-btn js-header-warning-close-btn" onclick="$('.js-header-warning').fadeOut('slow')">
#       </div>
#      </div>
#     </div>
#    </footer>
#    <script src="//static8.orstatic.com/bundles/js/v/common.ycCYHGW4Ay4kN8dRvWX2X9sDT80V_diwwsF29LO-gg01-v593.js">
#    </script>
#    <script src="//static7.orstatic.com/bundles/js/v/or/search.P6aVFxWT9y3Ke1jIL9sx9V9bfUK2UMdcGOWDt93ktVg1-v593.js">
#    </script>
#    <script src="//static5.orstatic.com/bundles/js/v/or/poi-list.Si-HSFpjiMpv9KXKOtIphxkcsceOHvtkcE1h6LJbUq81-v593.js">
#    </script>
#    <div class="cookies-agreement-wrapper" data-controller="CookiesAgreement" id="cookies-agreement">
#     <div class="cookies-agreement-content" data-nosnippet="">
#      <div class="cookies-agreement-text">
#       This website uses cookies to improve your website experience. By continuing to browse, you are agreeing to our
#       <a href="https://www.openrice.com/info/tnc/OR-pp-en.html" target="_blank">
#        <span>
#         use of cookies and Privacy Policy
#        </span>
#       </a>
#       .
#      </div>
#      <button class="cookies-agreement-button js-cookies-agreement-button">
#       Agree
#      </button>
#     </div>
#    </div>
#   </div>
#   <div class="flatpickr-calendar arrowTop" style="top: 310px; left: 358.5px; right: auto;" tabindex="-1">
#    <div class="flatpickr-month">
#     <span class="flatpickr-prev-month" style="display: none;">
#      <svg version="1.1" viewbox="0 0 17 17" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <g>
#       </g>
#       <path d="M5.207 8.471l7.146 7.147-0.707 0.707-7.853-7.854 7.854-7.853 0.707 0.707-7.147 7.146z">
#       </path>
#      </svg>
#     </span>
#     <span class="flatpickr-current-month">
#      <span class="cur-month" title="Scroll to increment">
#       Jul
#      </span>
#      <div class="numInputWrapper">
#       <input class="numInput cur-year" disabled="" max="2021" min="2021" pattern="\d*" title="Scroll to increment" type="text"/>
#       <span class="arrowUp">
#       </span>
#       <span class="arrowDown">
#       </span>
#      </div>
#     </span>
#     <span class="flatpickr-next-month" style="display: block;">
#      <svg version="1.1" viewbox="0 0 17 17" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <g>
#       </g>
#       <path d="M13.207 8.472l-7.854 7.854-0.707-0.707 7.146-7.146-7.146-7.148 0.707-0.707 7.854 7.854z">
#       </path>
#      </svg>
#     </span>
#    </div>
#    <div class="flatpickr-innerContainer">
#     <div class="flatpickr-rContainer">
#      <div class="flatpickr-weekdays">
#       <span class="flatpickr-weekday">
#        Sun
#       </span>
#       <span class="flatpickr-weekday">
#        Mon
#       </span>
#       <span class="flatpickr-weekday">
#        Tue
#       </span>
#       <span class="flatpickr-weekday">
#        Wed
#       </span>
#       <span class="flatpickr-weekday">
#        Thu
#       </span>
#       <span class="flatpickr-weekday">
#        Fri
#       </span>
#       <span class="flatpickr-weekday">
#        Sat
#       </span>
#      </div>
#      <div class="flatpickr-days" tabindex="-1">
#       <div class="dayContainer">
#        <span aria-label="Jun 27, 2021" class="flatpickr-day prevMonthDay disabled">
#         27
#        </span>
#        <span aria-label="Jun 28, 2021" class="flatpickr-day prevMonthDay disabled">
#         28
#        </span>
#        <span aria-label="Jun 29, 2021" class="flatpickr-day prevMonthDay disabled">
#         29
#        </span>
#        <span aria-label="Jun 30, 2021" class="flatpickr-day prevMonthDay disabled">
#         30
#        </span>
#        <span aria-label="Jul 1, 2021" class="flatpickr-day disabled">
#         1
#        </span>
#        <span aria-label="Jul 2, 2021" class="flatpickr-day disabled">
#         2
#        </span>
#        <span aria-label="Jul 3, 2021" class="flatpickr-day disabled">
#         3
#        </span>
#        <span aria-label="Jul 4, 2021" class="flatpickr-day disabled">
#         4
#        </span>
#        <span aria-label="Jul 5, 2021" class="flatpickr-day disabled">
#         5
#        </span>
#        <span aria-label="Jul 6, 2021" class="flatpickr-day disabled">
#         6
#        </span>
#        <span aria-label="Jul 7, 2021" class="flatpickr-day disabled">
#         7
#        </span>
#        <span aria-label="Jul 8, 2021" class="flatpickr-day disabled">
#         8
#        </span>
#        <span aria-label="Jul 9, 2021" class="flatpickr-day disabled">
#         9
#        </span>
#        <span aria-label="Jul 10, 2021" class="flatpickr-day disabled">
#         10
#        </span>
#        <span aria-label="Jul 11, 2021" class="flatpickr-day disabled">
#         11
#        </span>
#        <span aria-label="Jul 12, 2021" class="flatpickr-day disabled">
#         12
#        </span>
#        <span aria-label="Jul 13, 2021" class="flatpickr-day disabled">
#         13
#        </span>
#        <span aria-label="Jul 14, 2021" class="flatpickr-day disabled">
#         14
#        </span>
#        <span aria-label="Jul 15, 2021" class="flatpickr-day disabled">
#         15
#        </span>
#        <span aria-label="Jul 16, 2021" class="flatpickr-day disabled">
#         16
#        </span>
#        <span aria-label="Jul 17, 2021" class="flatpickr-day today" tabindex="-1">
#         17
#        </span>
#        <span aria-label="Jul 18, 2021" class="flatpickr-day" tabindex="-1">
#         18
#        </span>
#        <span aria-label="Jul 19, 2021" class="flatpickr-day" tabindex="-1">
#         19
#        </span>
#        <span aria-label="Jul 20, 2021" class="flatpickr-day" tabindex="-1">
#         20
#        </span>
#        <span aria-label="Jul 21, 2021" class="flatpickr-day" tabindex="-1">
#         21
#        </span>
#        <span aria-label="Jul 22, 2021" class="flatpickr-day" tabindex="-1">
#         22
#        </span>
#        <span aria-label="Jul 23, 2021" class="flatpickr-day" tabindex="-1">
#         23
#        </span>
#        <span aria-label="Jul 24, 2021" class="flatpickr-day" tabindex="-1">
#         24
#        </span>
#        <span aria-label="Jul 25, 2021" class="flatpickr-day" tabindex="-1">
#         25
#        </span>
#        <span aria-label="Jul 26, 2021" class="flatpickr-day" tabindex="-1">
#         26
#        </span>
#        <span aria-label="Jul 27, 2021" class="flatpickr-day" tabindex="-1">
#         27
#        </span>
#        <span aria-label="Jul 28, 2021" class="flatpickr-day" tabindex="-1">
#         28
#        </span>
#        <span aria-label="Jul 29, 2021" class="flatpickr-day" tabindex="-1">
#         29
#        </span>
#        <span aria-label="Jul 30, 2021" class="flatpickr-day" tabindex="-1">
#         30
#        </span>
#        <span aria-label="Jul 31, 2021" class="flatpickr-day" tabindex="-1">
#         31
#        </span>
#        <span aria-label="Aug 1, 2021" class="flatpickr-day nextMonthDay" data-next-month-label="AUG" tabindex="-1">
#         1
#        </span>
#        <span aria-label="Aug 2, 2021" class="flatpickr-day nextMonthDay" tabindex="-1">
#         2
#        </span>
#        <span aria-label="Aug 3, 2021" class="flatpickr-day nextMonthDay" tabindex="-1">
#         3
#        </span>
#        <span aria-label="Aug 4, 2021" class="flatpickr-day nextMonthDay" tabindex="-1">
#         4
#        </span>
#        <span aria-label="Aug 5, 2021" class="flatpickr-day nextMonthDay" tabindex="-1">
#         5
#        </span>
#        <span aria-label="Aug 6, 2021" class="flatpickr-day nextMonthDay" tabindex="-1">
#         6
#        </span>
#        <span aria-label="Aug 7, 2021" class="flatpickr-day nextMonthDay" tabindex="-1">
#         7
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="fb-root">
#   </div>
#   <div style="display: none; visibility: hidden;">
#    <script src="https://www.gstatic.com/firebasejs/7.7.0/firebase-app.js">
#    </script>
#    <script src="https://www.gstatic.com/firebasejs/7.7.0/firebase-analytics.js">
#    </script>
#    <script>
#     var firebaseConfig={apiKey:"AIzaSyBZIYIW4jqucUaJEfYcJhKwWiWQlj1gX7k",authDomain:"openrice-production.firebaseapp.com",databaseURL:"https://openrice-production.firebaseio.com",projectId:"openrice-production",storageBucket:"openrice-production.appspot.com",messagingSenderId:"681486649361",appId:"1:681486649361:web:50684b65ae62ca624a49b0",measurementId:"G-WM2DLEGHYP"};firebase.initializeApp(firebaseConfig);firebase.analytics();
#    </script>
#   </div>
#  </body>
# </html>

# %%
#location
for i in browserbs_sample.find_all('div',{'class':'icon-info address'}):
    print(i.a.string)
# Out:
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay
# Causeway Bay

# %%
#food type 
for i in browserbs_sample.find_all('div',{'class':'icon-info icon-info-food-name'}):
    food_type=[]
    for li in i.findAll('li'):
        food_type.append(li.string)
    print(food_type)
# Out:
# ['Guangdong', 'Hong Kong Style']
# ['International', 'All Day Breakfast']
# ['Korean', 'Korean Fried Chicken']
# ['Western', 'Pizza']
# ['Korean', 'Korean Fried Chicken']
# ['Western', 'Steak House']
# ['Korean', 'Ramen']
# ['Japanese', 'Sushi/Sashimi']
# ['Korean', 'Korean Fried Chicken']
# ['Japanese']
# ['Japanese', 'Seafood']
# ['Hong Kong Style', 'Snack Shop & Deli']
# ['American', 'Hamburger']
# ['Japanese', 'Sushi/Sashimi']
# ['Thai', 'Seafood']
# ['Japanese', 'Sushi/Sashimi']

# %%
#Name
for i in browserbs_sample.find_all('h2',{'class':'title-name'}):
    print(i.a.string)
# Out:
# Crab Fairy 蟹仙海鮮蒸碢大公館
# Mamaday
# Dodam Chicken (利舞臺廣場)
# Little Vegas
# Sodam Chicken
# The Grill Room (The L. Square)
# Kobekyu (Bartlock Centre) 吉列牛忌廉烏冬專門店 (百樂中心)
# Tsukiji Japanese Restaurant (Island Beverley) 築地日本料理 (金百利廣場)
# Bingo & Cook
# Toretore Hamayaki 漁獲浜燒
# Isono Suisan 磯野水產
# Hogology (Caroline Hill Road) 炊豕店 (加路連山道)
# Burgeroom (Fashion Walk)
# Xuan Sushi 玄鮨
# Milu Thai มิลู่ไทย
# Love Cafe 心之食堂

# %%
#price
for i in browserbs_sample.find_all('div',{'class':'icon-info icon-info-food-price'}):
    print(i.span.string)
# Out:
# $201-400
# $101-200
# $101-200
# $101-200
# $101-200
# $201-400
# $101-200
# $101-200
# $101-200
# $201-400
# $201-400
# $51-100
# $101-200
# Above $801
# $101-200
# $201-400

# %%
#bookmark
for i in browserbs_sample.find_all('div',{'class':'text bookmarkedUserCount js-bookmark-count'}):
    print(i.string)
# Out:
# 385
# 57.2K
# 43.1K
# 44.9K
# 58.4K
# 62.3K
# 23.2K
# 14.1K
# 35.2K
# 36.5K
# 18.4K
# 39.4K
# 49.6K
# 11.2K
# 22K
# 24.5K

# %%
#happy face
for i in browserbs_sample.find_all('span',{'class':'score score-big highlight'}):
    print(i.string)
# Out:
# 863
# 933
# 943
# 1035
# 995
# 763
# 639
# 1013
# 881
# 645
# 652
# 1188
# 544
# 657
# 879

# %%
#sad face
for i in browserbs_sample.find_all('span',{'class':'score highlight'}):
    print(i.string)
# Out:
# 9
# 22
# 38
# 69
# 49
# 18
# 18
# 22
# 8
# 5
# 32
# 68
# 4
# 6
# 43
